# %% [markdown]
# example text box

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from pathlib import Path

# %% [markdown]
# Information from USCS https://gis.cdc.gov/Cancer/USCS/#/AtAGlance/

# %%
#Rate of cancer cases in the entire US with ALL Cancers (Rate is per 100,000 people/ All Ages/ethnicity/sex)

csv_path1 = Path("CSV Files/USCSOverviewMap.csv")
r_of_new_can_us = pd.read_csv(csv_path1)
r_of_new_can_us.head()
# Out:
#           Area          Cancer Type       Year              Sex  \
# 0       Nevada  All Types of Cancer  2016-2020  Male and Female
# 1      Indiana  All Types of Cancer  2016-2020  Male and Female
# 2  Puerto Rico  All Types of Cancer  2016-2020  Male and Female
# 3   New Mexico  All Types of Cancer  2016-2020  Male and Female
# 4      Arizona  All Types of Cancer  2016-2020  Male and Female
#
#                         Race       Type   Age-Adjusted Rate  \
# 0  All Races and Ethnicities  Incidence  Data not presented
# 1  All Races and Ethnicities  Incidence  Data not presented
# 2  All Races and Ethnicities  Incidence               351.7
# 3  All Races and Ethnicities  Incidence                 369
# 4  All Races and Ethnicities  Incidence               376.6
#
#            Case Count          Population
# 0  Data not presented  Data not presented
# 1  Data not presented  Data not presented
# 2               71751            14737749
# 3               48358            10485106
# ...

# %%
csv_path2 = Path("CSV Files/USCSOverviewDeath.csv")
r_of_can_death_us = pd.read_csv(csv_path2)

# %%
#rate of all us cancer deaths with all ethnicity/race/cancers

r_of_can_death_us.head()
# Out:
#           Area          Cancer Type       Year              Sex  \
# 0  Puerto Rico  All Types of Cancer  2016-2020  Male and Female
# 1         Utah  All Types of Cancer  2016-2020  Male and Female
# 2       Hawaii  All Types of Cancer  2016-2020  Male and Female
# 3     Colorado  All Types of Cancer  2016-2020  Male and Female
# 4      Arizona  All Types of Cancer  2016-2020  Male and Female
#
#                         Race       Type  Age-Adjusted Rate  Death Count  \
# 0  All Races and Ethnicities  Mortality              107.0        26096
# 1  All Races and Ethnicities  Mortality              120.6        16297
# 2  All Races and Ethnicities  Mortality              125.7        12281
# 3  All Races and Ethnicities  Mortality              130.0        39806
# 4  All Races and Ethnicities  Mortality              132.3        61176
#
#    Population
# 0    16400391
# 1    15756196
# 2     7100371
# 3    28424625
# 4    35870327

# %%
#All Types of Cancer, All Ages, White, Non-Hispanic, Male and Female

csv_path3= Path("CSV Files/cancerdeath_non_hispanic_white.csv")
can_death_nonh_white = pd.read_csv(csv_path3)
can_death_nonh_white.head()
# Out:
#                    Area          Cancer Type       Year              Sex  \
# 0           Puerto Rico  All Types of Cancer  2016-2020  Male and Female
# 1  District of Columbia  All Types of Cancer  2016-2020  Male and Female
# 2                  Utah  All Types of Cancer  2016-2020  Male and Female
# 3              Colorado  All Types of Cancer  2016-2020  Male and Female
# 4               Arizona  All Types of Cancer  2016-2020  Male and Female
#
#                  Race       Type   Age-Adjusted Rate         Death Count  \
# 0  White Non-Hispanic  Mortality  Data not presented  Data not presented
# 1  White Non-Hispanic  Mortality                  97                1124
# 2  White Non-Hispanic  Mortality               122.1               14655
# 3  White Non-Hispanic  Mortality               130.4               32760
# 4  White Non-Hispanic  Mortality               135.4               48210
#
#            Population
# 0  Data not presented
# 1             1325483
# ...

# %%
#All Types of Cancer Deaths, All Ages, Black, Non-Hispanic, Male and Female Rate per 100,000 people
csv_path4=Path("CSV Files/cancerdeath_non_hispanic_black.csv")
can_death_nonh_black= pd.read_csv(csv_path4)
can_death_nonh_black.head()
# Out:
#            Area          Cancer Type       Year              Sex  \
# 0       Montana  All Types of Cancer  2016-2020  Male and Female
# 1   Puerto Rico  All Types of Cancer  2016-2020  Male and Female
# 2  South Dakota  All Types of Cancer  2016-2020  Male and Female
# 3       Wyoming  All Types of Cancer  2016-2020  Male and Female
# 4         Idaho  All Types of Cancer  2016-2020  Male and Female
#
#                  Race       Type   Age-Adjusted Rate         Death Count  \
# 0  Black Non-Hispanic  Mortality  Data not presented  Data not presented
# 1  Black Non-Hispanic  Mortality  Data not presented  Data not presented
# 2  Black Non-Hispanic  Mortality                87.8                  34
# 3  Black Non-Hispanic  Mortality                99.3                  26
# 4  Black Non-Hispanic  Mortality               104.7                  39
#
#            Population
# 0  Data not presented
# 1  Data not presented
# 2              115202
# 3               41650
# ...

# %%
#All Types of Cancer, All Ages, Hispanic, Male and Female
csv_path5=Path("CSV Files/cancerdeath_hispanic.csv")
can_death_hispanic= pd.read_csv(csv_path5)
can_death_hispanic.head()
# Out:
#             Area          Cancer Type       Year              Sex      Race  \
# 0    Puerto Rico  All Types of Cancer  2016-2020  Male and Female  Hispanic
# 1  West Virginia  All Types of Cancer  2016-2020  Male and Female  Hispanic
# 2        Vermont  All Types of Cancer  2016-2020  Male and Female  Hispanic
# 3    Mississippi  All Types of Cancer  2016-2020  Male and Female  Hispanic
# 4        Alabama  All Types of Cancer  2016-2020  Male and Female  Hispanic
#
#         Type   Age-Adjusted Rate         Death Count          Population
# 0  Mortality  Data not presented  Data not presented  Data not presented
# 1  Mortality                48.2                  48              150974
# 2  Mortality                59.5                  22               62597
# 3  Mortality                60.2                 152              485636
# 4  Mortality                60.8                 306             1075017

# %%
#All Types of Cancer, All Ages, Asian and Pacific Islander, Non-Hispanic, Male and Female Rate per 100,000 people
csv_path6=Path("CSV Files/cancerdeath_api.csv")
can_death_api= pd.read_csv(csv_path6)
can_death_api.head()
# Out:
#             Area          Cancer Type       Year              Sex  \
# 0    Puerto Rico  All Types of Cancer  2016-2020  Male and Female
# 1  West Virginia  All Types of Cancer  2016-2020  Male and Female
# 2       Delaware  All Types of Cancer  2016-2020  Male and Female
# 3    Connecticut  All Types of Cancer  2016-2020  Male and Female
# 4     New Jersey  All Types of Cancer  2016-2020  Male and Female
#
#                                       Race       Type   Age-Adjusted Rate  \
# 0  Asian and Pacific Islander Non-Hispanic  Mortality  Data not presented
# 1  Asian and Pacific Islander Non-Hispanic  Mortality                  63
# 2  Asian and Pacific Islander Non-Hispanic  Mortality                67.8
# 3  Asian and Pacific Islander Non-Hispanic  Mortality                68.8
# 4  Asian and Pacific Islander Non-Hispanic  Mortality                73.2
#
#           Death Count          Population
# 0  Data not presented  Data not presented
# ...
